# %%
# %sql
create schema if not exists formula1_inc.control;

# %%
# %sql
create table if not exists formula1_inc.control.batch_control(batch_id string,status string,created_timestamp timestamp,updated_timestamp timestamp);
