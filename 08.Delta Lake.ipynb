-- %%
create schema if not exists formula1.demo;

-- %%
create table if not exists formula1.demo.companies(
  name string,
  founded_date date,
  country string
)

-- %%
desc extended formula1.demo.companies

-- %%
insert into formula1.demo.companies values ("Apple","1970-01-01","USA")

-- %%
insert into  formula1.demo.companies values("Microsoft","1980-01-01","USA");
insert into  formula1.demo.companies values("Samsung","1975-01-01","South Korea");

-- %%
desc history formula1.demo.companies

-- %%
select * from formula1.demo.companies;

-- %%
restore table formula1.demo.companies to version as of 2;
