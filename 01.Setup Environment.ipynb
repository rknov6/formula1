-- %%
drop catalog formula11 cascade;
create catalog formula1;

-- %%
create schema formula1.landing;
create schema formula1.bronze;
create schema formula1.silver;
create schema formula1.gold;

-- %%
create volume formula1.landing.files

-- %%
%python
df = spark.read.options(header = True,inferSchema = True).csv("/Volumes/formula1/landing/files/circuits.csv")
df.display()

-- %%
select * from read_files('/Volumes/formula1/landing/files/circuits.csv',format => 'csv',header => true)
