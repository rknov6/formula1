# %%
# %run /Workspace/Users/chrknov6@hotmail.com/formula1/00.Configurations

# %%
# %run "/Workspace/Users/chrknov6@hotmail.com/formula1/001.Bronze helper functions"

# %%
from pyspark.sql.functions import col,current_timestamp

# %%
from pyspark.sql.types import StructField,StructType,StringType,IntegerType,DoubleType,DateType

# %%
con_schema = StructType([
                          StructField('constructorId', StringType(), True),
                          StructField('name', StringType(), True),
                          StructField('nationality', StringType(), True),
                          StructField('url', StringType())
])

# %%
con_df = spark.read.schema(con_schema).json(f'{path}/constructors.json')

# %%
con_df = add_ingestion(con_df)

# %%
con_df.write.mode("overwrite").saveAsTable(f'{catalog}.{bronze_schema}.constructors')
