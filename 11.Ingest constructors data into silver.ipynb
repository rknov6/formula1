# %%
from pyspark.sql.functions import col,initcap

# %%
# %run /Workspace/Users/chrknov6@hotmail.com/formula1/00.Configurations

# %%
bronze_table = f'{catalog}.{bronze_schema}.constructors'
silver_table = f'{catalog}.{silver_schema}.constructors'

# %%
constructors_df = (
                   spark.table(bronze_table)
                        .drop(col("url"))
                        .withColumnsRenamed(
                            {"constructorId":"constructor_id",
                             "name":"constructor_name"})
                        .dropDuplicates(["constructor_id"])
                        .withColumn("nationality",initcap(col("nationality")))
)
constructors_df.display()

# %%
constructors_df.write.mode("overwrite").saveAsTable(silver_table)
